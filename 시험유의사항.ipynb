# %%
시험지에 컨셉 설명 좀 있고 하단에 코드 채우기 셀 형태인듯?
패키지는 모두 설치됨. 
스켈레톤 코드 구조 변경 절대 금지 (import도 다 되어 있겠지?)
import 나 print 해도 점수에 영향은 없다고 함.

# %%
수업시간에 나왔던 빈칸은 일단 외워야 할 듯?

# %%
### 작성 필요 ### 라고 되어 있는곳 채우는 형태니까 한줄 그대로 외워야 할 듯?

# %%
각 모듈들이 어떤 입력값을 받고 어떤 값을 출력하는지 숙지하라고 함.

# %%
각 문제는 독립적으로 채점 됨. 연속된 코드여도 뒤에거만 맞아도 일단 맞는걸로 쳐준다는 듯.
